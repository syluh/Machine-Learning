# %%
#Importamos las librerias
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
#Se importa la data

peliculas = pd.read_csv("data/movies2.csv")

# %%
peliculas
# Out:
#                               franquicia  presupuesto  genero  \
# 0         Father of the Bride Collection          NaN  Comedy
# 1                                    NaN          NaN   Drama
# 2                      Friday Collection    3500000.0  Comedy
# 3                                    NaN          NaN  Comedy
# 4                                    NaN   12000000.0  Comedy
# ...                                  ...          ...     ...
# 1344     The Ouija Experiment Collection          NaN  Horror
# 1345                                 NaN          NaN     NaN
# 1346                                 NaN          NaN     NaN
# 1347  Texas Chainsaw Massacre Collection          NaN  Horror
# 1348                                 NaN          NaN     NaN
#
#                                          pagina_web    imdb_id lenguaje  \
# 0                                               NaN  tt0113041       en
# 1                                               NaN  tt0112749       en
# ...

# %%
#Seleccionar solo los valores numéricos
datos_numericos = peliculas.select_dtypes(np.number)

# %%
datos_numericos
# Out:
#       presupuesto  popularidad      ventas  duracion  puntuacion  n_votos
# 0             NaN     8.387519  76578911.0     106.0         5.7    173.0
# 1             NaN     0.894647    676525.0     106.0         6.7     13.0
# 2       3500000.0    14.569650  28215918.0      91.0         7.0    513.0
# 3             NaN     8.963037        32.0      87.0         6.0    124.0
# 4      12000000.0     9.592265  41205099.0      92.0         6.5    767.0
# ...           ...          ...         ...       ...         ...      ...
# 1344          NaN     1.642247         NaN      86.0         3.0     25.0
# 1345          NaN     0.352816         NaN      11.0         5.5      2.0
# 1346          NaN     0.110588         NaN      86.0         5.7      3.0
# 1347          NaN     9.742082         NaN      90.0         5.7     62.0
# 1348          NaN     0.121946         NaN       0.0         6.0      1.0
#
# [1349 rows x 6 columns]

# %%
# Reemplazamos los Nan por 0

datos_limpios = peliculas.select_dtypes(np.number).fillna(0)

# %%
datos_limpios
# Out:
#       presupuesto  popularidad      ventas  duracion  puntuacion  n_votos
# 0             0.0     8.387519  76578911.0     106.0         5.7    173.0
# 1             0.0     0.894647    676525.0     106.0         6.7     13.0
# 2       3500000.0    14.569650  28215918.0      91.0         7.0    513.0
# 3             0.0     8.963037        32.0      87.0         6.0    124.0
# 4      12000000.0     9.592265  41205099.0      92.0         6.5    767.0
# ...           ...          ...         ...       ...         ...      ...
# 1344          0.0     1.642247         0.0      86.0         3.0     25.0
# 1345          0.0     0.352816         0.0      11.0         5.5      2.0
# 1346          0.0     0.110588         0.0      86.0         5.7      3.0
# 1347          0.0     9.742082         0.0      90.0         5.7     62.0
# 1348          0.0     0.121946         0.0       0.0         6.0      1.0
#
# [1349 rows x 6 columns]

# %%
#Configurar las variables objetivo e independientes.

objetivo = "ventas"
#las variables independientes serian todas las demas menos ventas
independientes = datos_limpios.drop(columns=objetivo).columns

# %%
#Creamos el modelo y lo ajustamos

modelo = LinearRegression()
modelo.fit(X=datos_limpios[independientes], y=datos_limpios[objetivo])
# Out:
# LinearRegression()

# %%
#Agregamos las predicciones como una nueva columna del dataset original
peliculas["ventas_prediccion"] = modelo.predict(datos_limpios[independientes])

# %%
peliculas.keys()
# Out:
# Index(['franquicia', 'presupuesto', 'genero', 'pagina_web', 'imdb_id',
#        'lenguaje', 'popularidad', 'productores', 'pais', 'fecha_estreno',
#        'ventas', 'duracion', 'estado', 'titulo', 'puntuacion', 'n_votos',
#        'ventas_prediccion'],
#       dtype='object')

# %%
#Mostrar solo los campos ventas y ventas_predicción
peliculas[["ventas", "ventas_prediccion"]].head()
# Out:
#        ventas  ventas_prediccion
# 0  76578911.0       1.350624e+07
# 1    676525.0       5.503581e+06
# 2  28215918.0       3.876680e+07
# 3        32.0       9.331852e+06
# 4  41205099.0       6.737609e+07

# %%
#La columna ventas, son las ventas reales, y la columna ventas_prediccion son 
#los datos que el sistema hubiese predicho si 
#le hubiéramos pasado los datos correspondientes a sus  variables independientes.
